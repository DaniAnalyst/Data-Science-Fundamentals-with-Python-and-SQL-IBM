# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# **2-title.png**
# <img src = "attachment:3b470905-3932-488f-ac50-ae7b7c22f0c6.png">

# %% [markdown]
# **In this notebook, Data Science Tools and Ecosystem are summarized.**

# %% [markdown]
# **3-intro.png**
#
# <img src ="attachment:b44787f5-4e73-40d3-9dd1-d86bb8ac199a.png">

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. JavaScript
# 3. Java

# %% [markdown]
# **Objectives:**
#
# 1. List popular languages for Data Science
# 2. List popular libraries for Data Science
# 3. Convert 200 minutes to hours
# 4. Sum numeric values

# %% [markdown]
# **10-objectives.png**
# ![10-objectives.png](attachment:e7d68aef-b4d5-4ad4-add9-2e97c709dccb.png)

# %% [markdown]
# **4-dslanguages.png**
#
# <img src = "attachment:dda3aeb9-de95-40e1-b961-dcfe608337aa.png">

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Scikit-learn
# 2. Keras
# 3. TensorFlow

# %% [markdown]
# **5-dslibraries.png**
#
# <img src = "attachment:79d87cf7-f169-416b-8c30-f6fbf69530c8.png">

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# |GitHub|
# |Apache Spark|
# |Jupyter Notebook|

# %% [markdown]
# **6-dstools.png**
# <img src = "attachment:c4321479-a18f-45bf-8381-05c2eb75a51d.png">

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# **7-introarithmetic.png**
# <img src = "attachment:fbfa0cd1-40ef-4737-b988-23577b795c11.png">

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# **8-multiplyandaddintegers.png**
# ![8-multiplyandaddintegers.png](attachment:10497f29-d672-4e67-b753-6ad80ab0d968.png)

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %% [markdown]
# 200/60

# %% [markdown]
# **9-hourstominutes.png**
#
# ![9-hourstominutes.png](attachment:d707fd07-9c02-4036-b341-823728d20392.png)

# %% [markdown]
# ## Author
# Daniel Alfredo Sanchez Prada

# %% [markdown]
# **11-authordetails.png**
#
# ![11-authordetails.png](attachment:5485addc-ae4f-487a-b77f-d27d683e856e.png)
