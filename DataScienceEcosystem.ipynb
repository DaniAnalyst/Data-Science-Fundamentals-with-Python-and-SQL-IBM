# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# **2-title.png**
#
# ![2-title.png](attachment:ce24112d-82f4-45db-8fb2-5573dc73093e.png)

# %% [markdown]
# **In this notebook, Data Science Tools and Ecosystem are summarized.**

# %% [markdown]
# **3-intro.png**
#
# ![3-intro.png](attachment:5c3fc612-da6b-4aee-b0c9-bdcd84b405ac.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. Python
# 2. JavaScript
# 3. Java

# %% [markdown]
# **4-dslanguages.png**
#
# ![4-dslanguages.png](attachment:40a3612e-fac9-485b-84c0-b59e160e475c.png)

# %% [markdown]
# **Objectives:**
#
# 1. List popular languages for Data Science
# 2. List popular libraries for Data Science
# 3. Convert 200 minutes to hours
# 4. Sum numeric values

# %% [markdown]
# **10-objectives.png**
#
# ![10-objectives.png](attachment:2c76f724-a7ba-4eec-b3a2-bda3c5a82b95.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. Scikit-learn
# 2. Keras
# 3. TensorFlow

# %% [markdown]
# **5-dslibraries.png**
#
# ![5-dslibraries.png](attachment:3b41555e-5853-4a5a-84b2-7b02f2a4e11b.png)

# %% [markdown]
# | Data Science Tools |
# |--------------------|
# |GitHub|
# |Apache Spark|
# |Jupyter Notebook|

# %% [markdown]
# **6-dstools.png**
# ![6-dstools.png](attachment:f56b0823-0beb-4a8b-90f5-992ca6704dca.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %% [markdown]
# **7-introarithmetic.png**
#
# ![7-introarithmetic.png](attachment:1f47c884-88a2-417d-b1f3-dff7e88c90e7.png)

# %% [markdown]
# This a simple arithmetic expression to mutiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# **8-multiplyandaddintegers.png**
#
# ![8-multiplyandaddintegers.png](attachment:34e652ba-908f-4fa0-adf4-8b705903c777.png)

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# **9-hourstominutes.png**
#
# ![9-hourstominutes.png](attachment:b982fe60-068c-4b41-9db7-85b740eef484.png)

# %% [markdown]
# ## Author
# Daniel Alfredo Sanchez Prada

# %% [markdown]
# **11-authordetails.png**
#
# ![11-authordetails.png](attachment:37c99e15-3dba-4709-935b-965e352e3128.png)

# %% [markdown]
# **1-notebook.png**
#
# ![1-notebook.png](attachment:83a0bd6d-e3e4-4e16-9e37-aeeb4bea6df6.png)
